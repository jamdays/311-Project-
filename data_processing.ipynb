# %%
import pandas as pd

# %%
df = pd.read_csv("./Data/cleaned_data_combined_modified.csv")
df["Q2: How many ingredients would you expect this food item to contain?"].dtype == "O"
df["id"].dtype == "int64"
# Out:
# True

# %%
df
# Out:
#           id  \
# 0     716549
# 1     715742
# 2     727333
# 3     606874
# 4     505318
# ...      ...
# 1639  413395
# 1640  386750
# 1641  617178
# 1642  630128
# 1643  628736
#
#       Q1: From a scale 1 to 5, how complex is it to make this food? (Where 1 is the most simple, and 5 is the most complex)  \
# 0                                                     3
# 1                                                     4
# 2                                                     3
# 3                                                     4
# 4                                                     2
# ...                                                 ...
# 1639                                                  2
# 1640                                                  3
# 1641                                                  2
# 1642                                                  1
# 1643                                                  4
#
# ...

# %%
# This also includes the question so there is one index
def get_time_eaten(frame):
    cols = frame.iloc[:,3]
    cols = [(i.find("Week day lunch") != -1, i.find("Week day dinner") != -1, i.find("Weekend lunch") != -1, i.find("Weekend dinner") != -1, i.find("At a party") != -1, i.find("Late night snack") != -1) for i in cols]
    #so that it doesnt have the trash guy. Also it is backwards I guess?
    return cols[0: len(cols) -1]
get_time_eaten(df)
# Out:
# [(True, False, False, False, True, True),
#  (True, False, False, False, True, True),
#  (True, True, True, True, False, False),
#  (True, True, True, True, True, True),
#  (True, True, True, True, True, False),
#  (True, True, True, True, True, True),
#  (True, False, False, False, False, False),
#  (True, True, True, True, True, True),
#  (False, True, True, True, True, True),
#  (True, True, True, True, True, True),
#  (False, False, False, True, True, False),
#  (True, True, True, True, True, True),
#  (True, True, True, True, True, True),
#  (False, False, True, True, True, False),
#  (True, True, True, True, True, True),
#  (False, False, True, True, True, True),
#  (True, True, True, True, True, False),
#  (True, True, True, True, True, True),
#  (True, True, True, True, True, True),
#  (False, True, False, False, True, False),
#  (False, True, False, True, True, True),
#  (True, True, True, True, True, True),
#  (True, True, True, True, True, True),
# ...

# %%
def get_price(frame):
    cols = frame.iloc[:, 4]
    cols = [max(find_digits(str(x))) if len(find_digits(str(x))) != 0 else words_to_digits(str(x)) for x in cols]
    return cols[0: len(cols) -1]
def find_digits(string):
    return [x for x in range(51) if string.find(str(x)) != -1]
def words_to_digits(string):
    tens = {
        "twenty": 20, "thirty": 30, "forty": 40, "fifty": 50
    }
    ones = {
        "one": 1, "two": 2, "three": 3, "four": 4, "five": 5,
        "six": 6, "seven": 7, "eight": 8, "nine": 9
    }
    teens = {
        "ten": 10, "eleven": 11, "twelve": 12, "thirteen": 13, "fourteen": 14,
        "fifteen": 15, "sixteen": 16, "seventeen": 17, "eighteen": 18, "nineteen": 19
    }
    for key in tens.keys():
        if string.lower().find(key) != -1:
            print (tens[key])
            return tens[key]
    for key in teens.keys():
        if string.lower().find(key) != -1:
            print (teens[key])
            return teens[key]
    for key in ones.keys():
        if string.lower().find(key) != -1:
            print (ones[key])
            return ones[key]
    return -1

get_price(df)
# Out:
# 30
# 6
# 10
# [5,
#  5,
#  10,
#  3,
#  5,
#  15,
#  1,
#  20,
#  3,
#  4,
#  20,
#  12,
#  6,
#  30,
#  10,
#  7,
#  5,
#  12,
#  3,
#  8,
#  15,
#  3,
#  8,
#  10,
#  25,
#  30,
#  6,
#  10,
#  5,
#  25,
#  20,
#  8,
#  3,
#  15,
#  10,
#  13,
#  10,
#  4,
#  5,
#  6,
#  4,
#  13,
#  13,
#  3,
#  7,
#  20,
#  15,
#  15,
#  15,
#  10,
#  5,
#  15,
#  12,
#  15,
#  5,
#  3,
#  7,
#  15,
#  15,
#  40,
#  15,
#  6,
#  15,
#  20,
#  5,
#  7,
#  20,
#  6,
#  15,
#  3,
#  9,
#  15,
#  7,
#  12,
#  30,
#  5,
#  5,
#  6,
#  5,
#  6,
#  15,
#  5,
#  6,
#  18,
#  5,
#  25,
#  5,
#  7,
#  2,
#  5,
#  15,
#  15,
#  10,
#  5,
#  4,
#  10,
#  10,
#  20,
#  3,
#  4,
#  5,
#  6,
#  5,
#  6,
#  20,
#  10,
#  5,
#  50,
#  20,
#  50,
#  15,
#  3,
#  5,
#  50,
#  17,
#  3,
#  10,
#  5,
#  5,
#  4,
#  22,
#  5,
#  8,
#  16,
#  25,
#  25,
#  5,
#  25,
#  25,
#  3,
#  5,
#  5,
#  12,
#  7,
#  5,
#  5,
#  3,
#  7,
#  4,
#  5,
#  5,
#  20,
#  14,
#  5,
#  15,
#  5,
#  20,
#  50,
#  20,
#  15,
#  7,
#  10,
# ...
